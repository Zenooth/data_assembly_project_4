# %%
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
from time import sleep
import requests
import urllib
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from robobrowser import RoboBrowser
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By

# %%
firefox = r'C:\Users\User\Downloads\geckodriver-v0.20.1-win64\geckodriver'
login = 'https://jobscentral.com.sg/login'
url = 'https://jobscentral.com.sg'
search_terms = ['data scientist', 'data analyst', 'business intelligence', 'business analyst', 'data science', 'language processing', 'software engineer']

# %%
profile = webdriver.FirefoxProfile()
profile.set_preference("permissions.default.image", 2)

# %%
job_links = []
driver = webdriver.Firefox(executable_path=firefox, firefox_profile=profile)
driver.get(login)
sleep(1)

username = driver.find_element_by_id("inputEmail")
password = driver.find_element_by_id("inputPassword")
username.send_keys("goh.yu.xuan@gmail.com")
password.send_keys("Pa55worD")
driver.find_element_by_id("submitBtn").click()

sleep(5)

# driver.(url)

for search_term in search_terms:
    search = driver.find_element_by_xpath('//div[1]/div/input')
    search.clear()
    search.send_keys(search_term)
    search.send_keys(Keys.RETURN)

    sleep(2)

    html = driver.page_source
    soup = BeautifulSoup(html, 'lxml')

    for item in soup.find_all(attrs={"class": "job-title"}):
        if item.get('href') not in job_links:
            job_links.append(item.get('href'))
          
    a = soup.find(attrs={"aria-label": "Next"})
    
    while a:
        urlend = a.get('href')
        driver.get(url+urlend)
        sleep(3)
        html = driver.page_source
        soup = BeautifulSoup(html, 'lxml')
        a = soup.find(attrs={"aria-label": "Next"})
        if urlend == a.get('href'):
            break
        for item in soup.find_all(attrs={"class": "job-title"}):
            if item.get('href') not in job_links:
                job_links.append(item.get('href'))
driver.close()

# %%
company = []
title = []
category = []
position = []
job_type = []
qualification = []
salary = []
temp = []

# %%
driver = webdriver.Firefox(executable_path=firefox, firefox_profile=profile)
driver.get(login)
sleep(1)

username = driver.find_element_by_id("inputEmail")
password = driver.find_element_by_id("inputPassword")
username.send_keys("goh.yu.xuan@gmail.com")
password.send_keys("Pa55worD")
driver.find_element_by_id("submitBtn").click()

sleep(5)

count = 0
for job_link in job_links[:172]:
    driver.get(url+job_link)
    sleep(2)
    html = driver.page_source
    asd = BeautifulSoup(html, 'lxml')
    stuff = asd.find_all('div', {'class':'col-9 col-sm-7 col-md-9', '_ngcontent-c10':''})
    try:
        company.append(asd.find('span', {'class':"d-block d-sm-inline"}).text)
    except:
        company.append(0)
    try:
        title.append(asd.find('h1').text)
    except:
        title.append(0)
    temp.append([(i.text,j.text) for i, j in zip(asd.find_all('div', {'class':"col-3 col-sm-5 col-md-3"}),asd.find_all('div', {'class':'col-9 col-sm-7 col-md-9', '_ngcontent-c10':''}))])
    count += 1
    print("\r {:.2f}% complete.".format(100*count/len(job_links)), end='', flush=True)
        
#     try:
#         job_type.append(stuff[0].text)
#     except:
#         job_type.append(0)
#     try:
#         position.append(stuff[1].text)
#     except:
#         job_type.append(0)
#     try:
#         category.append(stuff[2].text)
#     except:
#         category.append(0)
#     try:
#         qualification.append(stuff[3].text)
#     except:
#         qualification.append(0)
#     try:
#         salary.append(stuff[4].text)
#     except:
#         salary.append(0)
# Out:
#  32.03% complete.

# %%
for i, j in zip(asd.find_all('div', {'class':"col-3 col-sm-5 col-md-3"}),asd.find_all('div', {'class':'col-9 col-sm-7 col-md-9', '_ngcontent-c10':''})):
    print(i.text,j.text)
# Out:
# Job Nature: Permanent
# Position Level: Entry Level, Experienced
# Job Category:
#
# IT-Software/Development
#
#
# Qualification: Bachelor's / Honours
# Salary:
#
#         48,000 SGD - 72,000 SGD / Year

# %%
asd.find_all('div', {'class':'col-9 col-sm-7 col-md-9', '_ngcontent-c10':''})
# Out:
# [<div _ngcontent-c10="" class="col-9 col-sm-7 col-md-9">Permanent</div>,
#  <div _ngcontent-c10="" class="col-9 col-sm-7 col-md-9">Experienced</div>,
#  <div _ngcontent-c10="" class="col-9 col-sm-7 col-md-9">
#  <!-- --><span _ngcontent-c10="">
#  <a _ngcontent-c10="" class="category-link" href="/category/accounting">Account Management</a>,
#      </span><span _ngcontent-c10="">
#  <a _ngcontent-c10="" class="category-link" href="/category/sales">Corporate Sales</a>,
#      </span><span _ngcontent-c10="">
#  <a _ngcontent-c10="" class="category-link" href="/category/marketing">General Marketing</a>,
#      </span><span _ngcontent-c10="">
#  <a _ngcontent-c10="" class="category-link" href="/category/scientific">Sciences</a>
#  </span>
#  </div>,
#  <div _ngcontent-c10="" class="col-9 col-sm-7 col-md-9">Bachelor's / Honours</div>]

# %%
asd = BeautifulSoup(urllib.request.urlopen('https://jobscentral.com.sg/job/data-scientist-jgx718767wltvbfvd3l?iPath=JRKCVT'), 'html.parser')

# %%
Company            2573 non-null object
Title              2573 non-null object
Location           2573 non-null object
Address            2573 non-null object
Industry           2573 non-null object
Job Description    2573 non-null object
Seniority          2573 non-null object
Salary             2573 non-null object
Requirements       707 non-null object
JD                 2573 non-null object

# %%
# company
asd.find('span', {'class':"d-block d-sm-inline"}).text
# title
asd.find('h1').text
# category
asd.find('a', {'class':'category-link'}).text
# position level
# for _ in asd.find_all('div', {'class':'col-9 col-sm-7 col-md-9', '_ngcontent-c10':''}):
#     print(_.text)

asd.find_all('div', {'class':'col-9 col-sm-7 col-md-9', '_ngcontent-c10':''})[2].text
# Out:
# '\n\n\nLogin to view\n\n\n'

# %%
asd
# Out:
# <!DOCTYPE html>
# <html><head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
# <base href="/"/>
# <title>Data Scientist job at 3top Consulting Pte Ltd | JobsCentral Singapore</title>
# <link href="assets/images/favicon.png" rel="icon" type="image/x-icon"/>
# <script async="" defer="" src="https://www.google.com/recaptcha/api.js"></script>
# <script async="" src="https://apis.google.com/js/api.js"></script>
# <script>(function (w, d, l) {
#   var cookies = d.cookie.split(";").map(function (cookie) { return cookie.trim().split("="); });
#   function hasCookieName(name) {
#     return function (cookie) { return cookie[0] === name };
#   }
#   function getCookieValue() {
#     return function (cookie) { return cookie[1]; }
#   }
#   w[l] = w[l] || [];
#   w[l].push({
#     "site_id": cookies.filter(hasCookieName("siteId")).map(getCookieValue()).join(),
# ...
